# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from fredapi import Fred
from dotenv import load_dotenv
import os

load_dotenv()
fred = Fred(api_key=os.getenv('FRED_API_KEY'))

# %%
brent = fred.get_series('DCOILBRENTEU', observation_start='2024-01-01')
brent = brent.dropna()
brent.name = 'Brent_USD'
df = brent.to_frame()
df.index = pd.to_datetime(df.index)
df.head()
# Out:
#             Brent_USD
# 2024-01-02      76.24
# 2024-01-03      77.18
# 2024-01-04      75.79
# 2024-01-05      78.31
# 2024-01-08      75.47
